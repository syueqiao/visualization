# %%
#import needed packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
from PIL import Image # to open images
import requests
from io import BytesIO

# %%
response=requests.get('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkMJtURnuaAlX7BPUfj0yVuKa91TuDJjRg3g&s')
image_file=BytesIO(response.content)
image = Image.open(image_file)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
np.random.seed(833833)
plt.style.use('seaborn-v0_8-deep')
x = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(['isopod', 'sea slug', 'worm', 'shrimp', 'snail'])
y2 = np.array([110, 180, 240, 99, 220])

#
fig,ax = plt.subplots(figsize = (7,3))
ax.plot(x2, y2, color = 'green')
ax_image = fig.add_axes([0.25, 0.25, 0.25, 0.25])
ax_image.imshow(image)
ax_image.axis('off')

#saving visualizatioons
path = 'C:/Users/Yue Qiao/Documents/visualization/02_activities/assignments/participation'
filename = '/glorp_plot.png'
plt.savefig(path+filename, dpi = 10)

# %%
#more stuff
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('darkgrid')
sns.lineplot(data = tips,
             x = 'total_bill',
             y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
