# %% [markdown]
# Participation for Class 1 of Visualization module - using uv environment.

# %%
#import needed packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %% [markdown]
# - Explanation of the tuple output, very helpful!

# %%
np.random.seed(613)
x=np.arange(50)
y=np.random.randint(0, 100,50)
fig,ax=plt.subplots(1,1,figsize=(5, 3))
fig.patch.set_facecolor("#e77e7e")
ax.patch.set_facecolor("#7ee793")
ax.tick_params(axis='both', colors='#7ee793')

# %% [markdown]
# - philosophy of data visualization, what is neutrality?
# - what types of data lend themselves to certain types of relationships?
# - Gestalt principles for visualization design
# - overall principals of how the brain percieves things, e.g., closures, continuous, etc.
# - resources for different types of data visualization: https://datavizcatalogue.com/index.html and https://github.com/Financial-Times/chart-doctor/blob/main/visual-vocabulary/README.md
